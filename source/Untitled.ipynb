# %%
#Code for AV LTFS Hackathon April 2019
#read the training file
import numpy as np
import pandas as pd

# %%
training = pd.read_csv("../data/train_aox2Jxw/train.csv")
pd.set_option('display.max_columns', None) #to see all columns
training.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
# 4    539055             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  \
# 0               45                1441      01-01-84        Salaried
# 1               45                1502      31-07-85   Self employed
# 2               45                1497      24-08-85   Self employed
# 3               45                1501      30-12-93   Self employed
# 4               45                1495      09-12-77   Self employed
#
#   DisbursalDate  State_ID  Employee_code_ID  MobileNo_Avl_Flag  Aadhar_flag  \
# ...

# %%
#check datatypes
training.dtypes

#subset variables that can be used for modelling
training = training[['disbursed_amount','asset_cost','ltv','Date.of.Birth','Employment.Type','DisbursalDate','MobileNo_Avl_Flag',
                    'Aadhar_flag','PAN_flag','VoterID_flag','Driving_flag','Passport_flag','']]
#extract age from dob

#apply logistic regression

#test dataset read

#test datset process columns

#apply logistic reggresion on test set and predict

#report submission
# Out:
# UniqueID                                 int64
# disbursed_amount                         int64
# asset_cost                               int64
# ltv                                    float64
# branch_id                                int64
# supplier_id                              int64
# manufacturer_id                          int64
# Current_pincode_ID                       int64
# Date.of.Birth                           object
# Employment.Type                         object
# DisbursalDate                           object
# State_ID                                 int64
# Employee_code_ID                         int64
# MobileNo_Avl_Flag                        int64
# Aadhar_flag                              int64
# PAN_flag                                 int64
# VoterID_flag                             int64
# Driving_flag                             int64
# Passport_flag                            int64
# PERFORM_CNS.SCORE                        int64
# ...
